# %% [markdown]
# <a href="https://colab.research.google.com/github/Putri-andini-rpe/Pemrograman-Dasar/blob/main/Contoh_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sistem_penilaian_semua(data_siswa):
    # --- Tipe data non-primitif ---
    mata_pelajaran = ("Matematika", "Fisika", "Informatika")  # tuple
    tips_belajar = {
        "Matematika": "Latihan soal setiap hari",
        "Fisika": "Pahami konsep, jangan hafalan",
        "Informatika": "Perbanyak praktik coding"
    }  # dictionary
    tambahan = {"Jangan menyerah", "Terus semangat"}  # set

    # Perulangan untuk setiap siswa (data_siswa = list of dict)
    for siswa in data_siswa:
        nama = siswa["nama"]
        nilai = siswa["nilai"]
        status_lulus = False
        pesan = ""
        rekomendasi = []

        # --- Percabangan IF, ELIF, ELSE ---
        if nilai >= 90:
            pesan = "Nilai kamu sangat baik! 🏆"
            status_lulus = True
        elif nilai >= 70:
            pesan = "Kamu lulus, tapi masih bisa ditingkatkan."
            status_lulus = True
        else:
            pesan = "Kamu belum lulus, tetap semangat belajar!"
            status_lulus = False

        # --- Perulangan FOR ---
        for pelajaran in mata_pelajaran:
            if nilai < 85:
                rekomendasi.append(tips_belajar[pelajaran])

        # --- Perulangan WHILE ---
        target = 100
        selisih = target - nilai
        langkah = 0
        while selisih > 0:
            langkah += 1
            selisih -= 5  # misalnya tiap minggu naik 5 poin

        # --- OUTPUT ---
        print("=" * 50)
        print(f"Nama: {nama}")
        print(f"Nilai: {nilai}")
        print(f"Status Lulus: {status_lulus}")
        print(f"Pesan: {pesan}")

        print("\nRekomendasi Belajar:")
        if rekomendasi:
            for r in rekomendasi:
                print(f"- {r}")
        else:
            print("- Tidak perlu rekomendasi tambahan 👍")

        print("\nMotivasi Tambahan:")
        for t in tambahan:
            print(f"- {t}")

        print(f"\nPerkiraan waktu untuk nilai sempurna: {langkah} minggu\n")


# --- Daftar siswa (list of dictionary) ---
daftar_siswa = [
    {"nama": "Vina Aprilia", "nilai": 78},
    {"nama": "Anas mutiara dewa", "nilai": 92},
    {"nama": "Rina cintya ayu", "nilai": 65},
    {"nama": "Sri Melati", "nilai": 84},
    {"nama": "Andini Putri", "nilai": 99}
]

# --- Pemanggilan Fungsi ---
sistem_penilaian_semua(daftar_siswa)
# Out:
# ...
# Nama: Vina Aprilia
# Nilai: 78
# Status Lulus: True
# Pesan: Kamu lulus, tapi masih bisa ditingkatkan.
#
# Rekomendasi Belajar:
# - Latihan soal setiap hari
# - Pahami konsep, jangan hafalan
# - Perbanyak praktik coding
#
# Motivasi Tambahan:
# - Terus semangat
# - Jangan menyerah
#
# Perkiraan waktu untuk nilai sempurna: 5 minggu
#
# ...
# Nama: Anas mutiara dewa
# Nilai: 92
# Status Lulus: True
# Pesan: Nilai kamu sangat baik! 🏆
#
# Rekomendasi Belajar:
# - Tidak perlu rekomendasi tambahan 👍
#
# Motivasi Tambahan:
# - Terus semangat
# - Jangan menyerah
#
# Perkiraan waktu untuk nilai sempurna: 2 minggu
#
# ...
# Nama: Rina cintya ayu
# Nilai: 65
# Status Lulus: False
# Pesan: Kamu belum lulus, tetap semangat belajar!
#
# Rekomendasi Belajar:
# - Latihan soal setiap hari
# - Pahami konsep, jangan hafalan
# - Perbanyak praktik coding
#
# Motivasi Tambahan:
# - Terus semangat
# - Jangan menyerah
#
# Perkiraan waktu untuk nilai sempurna: 7 minggu
#
# ...
# Nama: Sri Melati
# Nilai: 84
# ...
